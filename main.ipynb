# %%
from google import genai

client = genai.Client(api_key="AIzaSyDVjkIwX3Jdts8Xd7WpdLMwm5VyH3N_XXg")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Hello, how are you today !"
)
print(response.text)
# Out:
# Hello! As an AI, I don't experience feelings or have a 'day' in the human sense, but I'm functioning perfectly and ready to assist you.
#
# Thank you for asking! How are *you* doing today?
