# %%
import tkinter as tk
import time

def start_timer():
    global running
    if not running:
        running = True
        count_time()

def stop_timer():
    global running
    running = False

def reset_timer():
    global running, start_time
    running = False
    start_time = None
    label_time.config(text="00:00:00")

def count_time():
    if running:
        global start_time
        if start_time is None:
            start_time = time.time()

        elapsed_time = time.time() - start_time
        mins, secs = divmod(elapsed_time, 60)
        hours, mins = divmod(mins, 60)
        label_time.config(text=f"{int(hours):02}:{int(mins):02}:{int(secs):02}")
        root.after(1000, count_time)

running = False
start_time = None

root = tk.Tk()
root.title("Stopwatch")

label_time = tk.Label(root, text="00:00:00", font=("Arial", 40), width=10)
label_time.pack(pady=10)

start_button = tk.Button(root, text="Start", command=start_timer, font=("Arial", 14))
start_button.pack(side="left", padx=10)

stop_button = tk.Button(root, text="Stop", command=stop_timer, font=("Arial", 14))
stop_button.pack(side="left", padx=10)

reset_button = tk.Button(root, text="Reset", command=reset_timer, font=("Arial", 14))
reset_button.pack(side="left", padx=10)

root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk menampilkan teks yang dimasukkan ke dalam label
def tampilkan_teks():
    teks = entry.get()  # Mengambil teks dari entry
    label_hasil.config(text="Teks yang dimasukkan: " + teks)

# Membuat window utama
root = tk.Tk()
root.title("Contoh Aplikasi Tkinter")  # Judul window
root.geometry("300x200")  # Ukuran window

# Membuat label
label_instruksi = tk.Label(root, text="Masukkan teks di bawah ini:")
label_instruksi.pack(pady=10)  # Menambahkan padding vertikal

# Membuat entry (kotak input)
entry = tk.Entry(root, width=30)
entry.pack(pady=10)

# Membuat tombol
tombol = tk.Button(root, text="Tampilkan Teks", command=tampilkan_teks)
tombol.pack(pady=10)

# Membuat label untuk menampilkan hasil
label_hasil = tk.Label(root, text="")
label_hasil.pack(pady=10)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk konversi suhu Celcius ke Fahrenheit
def celcius_ke_fahrenheit():
    try:
        celcius = float(entry_celcius.get())  # Mengambil nilai dari input celcius
        fahrenheit = (celcius * 9/5) + 32  # Rumus konversi Celcius ke Fahrenheit
        label_hasil.config(text=f"{celcius}°C = {fahrenheit}°F")  # Menampilkan hasil
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")  # Error handling

# Fungsi untuk konversi suhu Fahrenheit ke Celcius
def fahrenheit_ke_celcius():
    try:
        fahrenheit = float(entry_fahrenheit.get())  # Mengambil nilai dari input fahrenheit
        celcius = (fahrenheit - 32) * 5/9  # Rumus konversi Fahrenheit ke Celcius
        label_hasil.config(text=f"{fahrenheit}°F = {celcius}°C")  # Menampilkan hasil
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")  # Error handling

# Membuat window utama
root = tk.Tk()
root.title("Converter Satuan Suhu")  # Judul window
root.geometry("400x300")  # Ukuran window

# Membuat label dan entry untuk input suhu Celcius
label_celcius = tk.Label(root, text="Masukkan suhu dalam Celcius:")
label_celcius.pack(pady=5)
entry_celcius = tk.Entry(root)
entry_celcius.pack(pady=5)

# Membuat tombol konversi Celcius ke Fahrenheit
button_celcius_ke_fahrenheit = tk.Button(root, text="Convert ke Fahrenheit", command=celcius_ke_fahrenheit)
button_celcius_ke_fahrenheit.pack(pady=10)

# Membuat label dan entry untuk input suhu Fahrenheit
label_fahrenheit = tk.Label(root, text="Masukkan suhu dalam Fahrenheit:")
label_fahrenheit.pack(pady=5)
entry_fahrenheit = tk.Entry(root)
entry_fahrenheit.pack(pady=5)

# Membuat tombol konversi Fahrenheit ke Celcius
button_fahrenheit_ke_celcius = tk.Button(root, text="Convert ke Celcius", command=fahrenheit_ke_celcius)
button_fahrenheit_ke_celcius.pack(pady=10)

# Membuat label untuk menampilkan hasil konversi
label_hasil = tk.Label(root, text="Hasil konversi akan muncul di sini.", font=("Arial", 12))
label_hasil.pack(pady=20)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk menambah angka ke layar kalkulator
def tekan_angka(angka):
    current = entry.get()
    entry.delete(0, tk.END)  # Menghapus angka yang ada di entry
    entry.insert(tk.END, current + str(angka))  # Menambahkan angka yang ditekan

# Fungsi untuk menghitung hasil perhitungan
def hitung():
    try:
        expression = entry.get()  # Mengambil ekspresi yang ada di entry
        result = eval(expression)  # Menghitung ekspresi (penjumlahan, pengurangan, dll)
        entry.delete(0, tk.END)
        entry.insert(tk.END, str(result))  # Menampilkan hasil
    except Exception as e:
        entry.delete(0, tk.END)
        entry.insert(tk.END, "Error")

# Fungsi untuk menghapus angka di layar kalkulator
def clear():
    entry.delete(0, tk.END)

# Membuat window utama
root = tk.Tk()
root.title("Kalkulator Sederhana")  # Judul window
root.geometry("400x500")  # Ukuran window

# Membuat entry untuk menampilkan angka yang dimasukkan
entry = tk.Entry(root, width=16, font=("Arial", 24), borderwidth=2, relief="solid", justify="right")
entry.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# Membuat tombol angka 0-9 dan operasi dasar tanpa perulangan
# Tombol angka
button_1 = tk.Button(root, text="1", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(1))
button_1.grid(row=1, column=0, padx=5, pady=5)

button_2 = tk.Button(root, text="2", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(2))
button_2.grid(row=1, column=1, padx=5, pady=5)

button_3 = tk.Button(root, text="3", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(3))
button_3.grid(row=1, column=2, padx=5, pady=5)

button_4 = tk.Button(root, text="4", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(4))
button_4.grid(row=2, column=0, padx=5, pady=5)

button_5 = tk.Button(root, text="5", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(5))
button_5.grid(row=2, column=1, padx=5, pady=5)

button_6 = tk.Button(root, text="6", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(6))
button_6.grid(row=2, column=2, padx=5, pady=5)

button_7 = tk.Button(root, text="7", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(7))
button_7.grid(row=3, column=0, padx=5, pady=5)

button_8 = tk.Button(root, text="8", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(8))
button_8.grid(row=3, column=1, padx=5, pady=5)

button_9 = tk.Button(root, text="9", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(9))
button_9.grid(row=3, column=2, padx=5, pady=5)

button_0 = tk.Button(root, text="0", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(0))
button_0.grid(row=4, column=1, padx=5, pady=5)

# Tombol operasi matematika
button_plus = tk.Button(root, text="+", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("+"))
button_plus.grid(row=1, column=3, padx=5, pady=5)

button_minus = tk.Button(root, text="-", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("-"))
button_minus.grid(row=2, column=3, padx=5, pady=5)

button_multiply = tk.Button(root, text="×", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("*"))
button_multiply.grid(row=3, column=3, padx=5, pady=5)

button_divide = tk.Button(root, text="÷", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("/"))
button_divide.grid(row=4, column=3, padx=5, pady=5)

# Tombol Clear dan Hasil
button_clear = tk.Button(root, text="C", width=5, height=2, font=("Arial", 18), command=clear)
button_clear.grid(row=4, column=0, padx=5, pady=5)

button_equal = tk.Button(root, text="=", width=5, height=2, font=("Arial", 18), command=hitung)
button_equal.grid(row=4, column=2, padx=5, pady=5)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk menambah angka ke layar kalkulator
def tekan_angka(angka):
    current = entry.get()
    entry.delete(0, tk.END)
    entry.insert(tk.END, current + str(angka))

# Fungsi untuk melakukan perhitungan berdasarkan operator yang dipilih
def hitung():
    try:
        # Ambil ekspresi dari Entry
        expression = entry.get()

        # Tentukan operator dan pisahkan angka
        if '+' in expression:
            num1, num2 = expression.split('+')
            result = float(num1) + float(num2)
        elif '-' in expression:
            num1, num2 = expression.split('-')
            result = float(num1) - float(num2)
        elif '*' in expression:
            num1, num2 = expression.split('*')
            result = float(num1) * float(num2)
        elif '/' in expression:
            num1, num2 = expression.split('/')
            if float(num2) != 0:
                result = float(num1) / float(num2)
            else:
                result = "Error (division by zero)"
        else:
            result = "Error (invalid operator)"

        entry.delete(0, tk.END)
        entry.insert(tk.END, str(result))
    except Exception as e:
        entry.delete(0, tk.END)
        entry.insert(tk.END, "Error")

# Fungsi untuk menghapus angka di layar kalkulator
def clear():
    entry.delete(0, tk.END)

# Membuat window utama
root = tk.Tk()
root.title("Kalkulator Sederhana")  # Judul window
root.geometry("400x500")  # Ukuran window

# Membuat entry untuk menampilkan angka yang dimasukkan
entry = tk.Entry(root, width=16, font=("Arial", 24), borderwidth=2, relief="solid", justify="right")
entry.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

# Tombol angka 0-9 dan operasi dasar
button_1 = tk.Button(root, text="1", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(1))
button_1.grid(row=1, column=0, padx=5, pady=5)

button_2 = tk.Button(root, text="2", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(2))
button_2.grid(row=1, column=1, padx=5, pady=5)

button_3 = tk.Button(root, text="3", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(3))
button_3.grid(row=1, column=2, padx=5, pady=5)

button_4 = tk.Button(root, text="4", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(4))
button_4.grid(row=2, column=0, padx=5, pady=5)

button_5 = tk.Button(root, text="5", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(5))
button_5.grid(row=2, column=1, padx=5, pady=5)

button_6 = tk.Button(root, text="6", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(6))
button_6.grid(row=2, column=2, padx=5, pady=5)

button_7 = tk.Button(root, text="7", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(7))
button_7.grid(row=3, column=0, padx=5, pady=5)

button_8 = tk.Button(root, text="8", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(8))
button_8.grid(row=3, column=1, padx=5, pady=5)

button_9 = tk.Button(root, text="9", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(9))
button_9.grid(row=3, column=2, padx=5, pady=5)

button_0 = tk.Button(root, text="0", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka(0))
button_0.grid(row=4, column=1, padx=5, pady=5)

# Tombol operasi matematika
button_plus = tk.Button(root, text="+", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("+"))
button_plus.grid(row=1, column=3, padx=5, pady=5)

button_minus = tk.Button(root, text="-", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("-"))
button_minus.grid(row=2, column=3, padx=5, pady=5)

button_multiply = tk.Button(root, text="×", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("*"))
button_multiply.grid(row=3, column=3, padx=5, pady=5)

button_divide = tk.Button(root, text="÷", width=5, height=2, font=("Arial", 18), command=lambda: tekan_angka("/"))
button_divide.grid(row=4, column=3, padx=5, pady=5)

# Tombol Clear dan Hasil
button_clear = tk.Button(root, text="C", width=5, height=2, font=("Arial", 18), command=clear)
button_clear.grid(row=4, column=0, padx=5, pady=5)

button_equal = tk.Button(root, text="=", width=5, height=2, font=("Arial", 18), command=hitung)
button_equal.grid(row=4, column=2, padx=5, pady=5)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

def ambil_input():
    # Mengambil teks yang dimasukkan ke dalam entry
    nilai = entry.get()  
    print(f"Nilai yang dimasukkan: {nilai}")

root = tk.Tk()

# Membuat Entry widget
entry = tk.Entry(root)
entry.pack(pady=20)

# Tombol untuk mengambil nilai dari entry
button = tk.Button(root, text="Ambil Input", command=ambil_input)
button.pack()

root.mainloop()
# Out:
# Nilai yang dimasukkan: kkk

# %%
import tkinter as tk

# Nilai tukar tetap, Anda bisa menyesuaikan atau menambahkan integrasi API untuk nilai tukar yang dinamis
nilai_tukar_idr_ke_usd = 0.000066  # 1 IDR = 0.000066 USD
nilai_tukar_usd_ke_idr = 15000     # 1 USD = 15000 IDR

# Fungsi untuk konversi IDR ke USD
def idr_ke_usd():
    try:
        idr = float(entry_idr.get())  # Mengambil nilai dari input IDR
        usd = idr * nilai_tukar_idr_ke_usd  # Mengonversi IDR ke USD
        label_hasil.config(text=f"Rp {idr} = ${usd:.2f} USD")  # Menampilkan hasil
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")  # Error handling

# Fungsi untuk konversi USD ke IDR
def usd_ke_idr():
    try:
        usd = float(entry_usd.get())  # Mengambil nilai dari input USD
        idr = usd * nilai_tukar_usd_ke_idr  # Mengonversi USD ke IDR
        label_hasil.config(text=f"${usd} = Rp {idr:.2f}")  # Menampilkan hasil
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")  # Error handling

# Membuat window utama
root = tk.Tk()
root.title("Converter Mata Uang")  # Judul window
root.geometry("400x300")  # Ukuran window

# Membuat label dan entry untuk input Rupiah
label_idr = tk.Label(root, text="Masukkan jumlah Rupiah (IDR):")
label_idr.pack(pady=5)
entry_idr = tk.Entry(root)
entry_idr.pack(pady=5)

# Membuat tombol konversi IDR ke USD
button_idr_ke_usd = tk.Button(root, text="Convert ke USD", command=idr_ke_usd)
button_idr_ke_usd.pack(pady=10)

# Membuat label dan entry untuk input Dolar AS
label_usd = tk.Label(root, text="Masukkan jumlah Dolar (USD):")
label_usd.pack(pady=5)
entry_usd = tk.Entry(root)
entry_usd.pack(pady=5)

# Membuat tombol konversi USD ke IDR
button_usd_ke_idr = tk.Button(root, text="Convert ke IDR", command=usd_ke_idr)
button_usd_ke_idr.pack(pady=10)

# Membuat label untuk menampilkan hasil konversi
label_hasil = tk.Label(root, text="Hasil konversi akan muncul di sini.", font=("Arial", 12))
label_hasil.pack(pady=20)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

def convert():
    temp = float(entry.get())
    from_unit = from_unit_var.get()
    to_unit = to_unit_var.get()

    if from_unit == "Celsius":
        if to_unit == "Fahrenheit":
            result = (temp * 9/5) + 32
        elif to_unit == "Kelvin":
            result = temp + 273.15
        else:
            result = temp
    elif from_unit == "Fahrenheit":
        if to_unit == "Celsius":
            result = (temp - 32) * 5/9
        elif to_unit == "Kelvin":
            result = (temp - 32) * 5/9 + 273.15
        else:
            result = temp
    elif from_unit == "Kelvin":
        if to_unit == "Celsius":
            result = temp - 273.15
        elif to_unit == "Fahrenheit":
            result = (temp - 273.15) * 9/5 + 32
        else:
            result = temp
    result_var.set(f"{result:.2f}")

root = tk.Tk()
root.title("Konversi Suhu")

entry = tk.Entry(root, font=("Arial", 14), width=10)
entry.grid(row=0, column=1, padx=10)

from_unit_var = tk.StringVar(value="Celsius")
to_unit_var = tk.StringVar(value="Fahrenheit")

from_unit_menu = tk.OptionMenu(root, from_unit_var, "Celsius", "Fahrenheit", "Kelvin")
from_unit_menu.grid(row=0, column=0)

to_unit_menu = tk.OptionMenu(root, to_unit_var, "Celsius", "Fahrenheit", "Kelvin")
to_unit_menu.grid(row=1, column=0)

convert_button = tk.Button(root, text="Konversi", command=convert, font=("Arial", 14))
convert_button.grid(row=1, column=1, pady=10)

result_var = tk.StringVar(value="Hasil: ")
result_label = tk.Label(root, textvariable=result_var, font=("Arial", 14))
result_label.grid(row=2, column=0, columnspan=2)

root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk konversi mata uang
def convert_currency():
    try:
        amount_idr = float(entry.get())
        conversion_rate = 0.000067  # Misal 1 IDR = 0.000067 USD (nilai tukar bisa disesuaikan)
        result = amount_idr * conversion_rate
        result_label.config(text=f"{amount_idr} IDR = {result:.2f} USD")
    except ValueError:
        result_label.config(text="Masukkan angka yang valid.")

# Membuat jendela utama
root = tk.Tk()
root.title("Konversi Mata Uang")

# Membuat label dan entry untuk memasukkan jumlah IDR
label = tk.Label(root, text="Masukkan Jumlah IDR:", font=("Arial", 12))
label.pack(pady=10)

entry = tk.Entry(root, font=("Arial", 12))
entry.pack(pady=10)

# Membuat tombol untuk mengonversi
button = tk.Button(root, text="Konversi", command=convert_currency, font=("Arial", 12))
button.pack(pady=10)

# Label untuk menampilkan hasil konversi
result_label = tk.Label(root, text="", font=("Arial", 12))
result_label.pack(pady=10)

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk menghitung konversi satuan panjang
def konversi():
    try:
        # Mengambil nilai panjang dalam meter dari entry
        meter = float(entry_meter.get())

        # Melakukan konversi
        yard = meter * 1.09361  # Mengonversi meter ke yard
        kilometer = meter * 0.001  # Mengonversi meter ke kilometer
        centimeter = meter * 100  # Mengonversi meter ke centimeter

        # Menampilkan hasil konversi
        label_yard.config(text=f"{yard:.2f} yard")
        label_kilometer.config(text=f"{kilometer:.3f} kilometer")
        label_centimeter.config(text=f"{centimeter} cm")
    except ValueError:
        label_yard.config(text="Masukkan angka yang valid")
        label_kilometer.config(text="")
        label_centimeter.config(text="")

# Membuat window utama
root = tk.Tk()
root.title("Konversi Satuan Panjang")  # Judul window
root.geometry("400x300")  # Ukuran window

# Membuat label dan entry untuk input panjang dalam meter
label_meter = tk.Label(root, text="Masukkan panjang dalam meter:", font=("Arial", 12))
label_meter.pack(pady=10)

entry_meter = tk.Entry(root, font=("Arial", 14))
entry_meter.pack(pady=10)

# Tombol untuk melakukan konversi
button_konversi = tk.Button(root, text="Konversi", width=20, font=("Arial", 14), command=konversi)
button_konversi.pack(pady=20)

# Label untuk menampilkan hasil konversi
label_yard = tk.Label(root, text="Hasil konversi ke yard:", font=("Arial", 12))
label_yard.pack()

label_kilometer = tk.Label(root, text="Hasil konversi ke kilometer:", font=("Arial", 12))
label_kilometer.pack()

label_centimeter = tk.Label(root, text="Hasil konversi ke centimeter:", font=("Arial", 12))
label_centimeter.pack()

# Menjalankan aplikasi
root.mainloop()

# %%
import tkinter as tk

# Fungsi untuk menghitung luas dan keliling
def hitung():
    try:
        if bangun_var.get() == "Persegi":
            sisi = float(entry_sisi.get())  # Mengambil nilai sisi dari entry
            luas = sisi * sisi  # Menghitung luas persegi
            keliling = 4 * sisi  # Menghitung keliling persegi
            label_hasil.config(text=f"Luas: {luas} | Keliling: {keliling}")
        elif bangun_var.get() == "Persegi Panjang":
            panjang = float(entry_panjang.get())  # Mengambil nilai panjang dari entry
            lebar = float(entry_lebar.get())  # Mengambil nilai lebar dari entry
            luas = panjang * lebar  # Menghitung luas persegi panjang
            keliling = 2 * (panjang + lebar)  # Menghitung keliling persegi panjang
            label_hasil.config(text=f"Luas: {luas} | Keliling: {keliling}")
        elif bangun_var.get() == "Lingkaran":
            jari_jari = float(entry_jari_jari.get())  # Mengambil nilai jari-jari dari entry
            luas = 3.14 * jari_jari * jari_jari  # Menghitung luas lingkaran (π * r²)
            keliling = 2 * 3.14 * jari_jari  # Menghitung keliling lingkaran (2 * π * r)
            label_hasil.config(text=f"Luas: {luas:.2f} | Keliling: {keliling:.2f}")
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")

# Membuat window utama
root = tk.Tk()
root.title("Kalkulator Bangun Datar")  # Judul window
root.geometry("400x400")  # Ukuran window

# Membuat label untuk memilih bangun datar
label_bangun = tk.Label(root, text="Pilih Bangun Datar:", font=("Arial", 12))
label_bangun.pack(pady=10)

# Opsi untuk memilih bangun datar
bangun_var = tk.StringVar()
bangun_var.set("Persegi")  # Default pilihan

radio_persegi = tk.Radiobutton(root, text="Persegi", variable=bangun_var, value="Persegi", font=("Arial", 12))
radio_persegi.pack()

radio_persegi_panjang = tk.Radiobutton(root, text="Persegi Panjang", variable=bangun_var, value="Persegi Panjang", font=("Arial", 12))
radio_persegi_panjang.pack()

radio_lingkaran = tk.Radiobutton(root, text="Lingkaran", variable=bangun_var, value="Lingkaran", font=("Arial", 12))
radio_lingkaran.pack()

# Label dan entry untuk input sesuai dengan pilihan
label_sisi = tk.Label(root, text="Masukkan sisi (untuk Persegi):", font=("Arial", 10))
label_panjang = tk.Label(root, text="Masukkan panjang (untuk Persegi Panjang):", font=("Arial", 10))
label_lebar = tk.Label(root, text="Masukkan lebar (untuk Persegi Panjang):", font=("Arial", 10))
label_jari_jari = tk.Label(root, text="Masukkan jari-jari (untuk Lingkaran):", font=("Arial", 10))

entry_sisi = tk.Entry(root, font=("Arial", 12))
entry_panjang = tk.Entry(root, font=("Arial", 12))
entry_lebar = tk.Entry(root, font=("Arial", 12))
entry_jari_jari = tk.Entry(root, font=("Arial", 12))

# Fungsi untuk mengupdate form input sesuai dengan bangun yang dipilih
def update_form():
    if bangun_var.get() == "Persegi":
        label_sisi.pack(pady=5)
        entry_sisi.pack(pady=5)
        label_panjang.pack_forget()
        entry_panjang.pack_forget()
        label_lebar.pack_forget()
        entry_lebar.pack_forget()
        label_jari_jari.pack_forget()
        entry_jari_jari.pack_forget()
    elif bangun_var.get() == "Persegi Panjang":
        label_sisi.pack_forget()
        entry_sisi.pack_forget()
        label_panjang.pack(pady=5)
        entry_panjang.pack(pady=5)
        label_lebar.pack(pady=5)
        entry_lebar.pack(pady=5)
        label_jari_jari.pack_forget()
        entry_jari_jari.pack_forget()
    elif bangun_var.get() == "Lingkaran":
        label_sisi.pack_forget()
        entry_sisi.pack_forget()
        label_panjang.pack_forget()
        entry_panjang.pack_forget()
        label_lebar.pack_forget()
        entry_lebar.pack_forget()
        label_jari_jari.pack(pady=5)
        entry_jari_jari.pack(pady=5)

# Memperbarui form input sesuai pilihan awal
update_form()

# Tombol untuk menghitung
button_hitung = tk.Button(root, text="Hitung", width=20, font=("Arial", 14), command=hitung)
button_hitung.pack(pady=20)

# Label untuk menampilkan hasil perhitungan
label_hasil = tk.Label(root, text="Luas dan Keliling akan muncul di sini.", font=("Arial", 14))
label_hasil.pack(pady=20)

# Menjalankan fungsi update_form() saat pilihan bangun datar berubah
bangun_var.trace("w", update_form)

# Menjalankan aplikasi
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/khawaritzmi/miniforge3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
# TypeError: update_form() takes 0 positional arguments but 3 were given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/khawaritzmi/miniforge3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
# TypeError: update_form() takes 0 positional arguments but 3 were given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/khawaritzmi/miniforge3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
# TypeError: update_form() takes 0 positional arguments but 3 were given
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/khawaritzmi/miniforge3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
# ...

# %%
import tkinter as tk

# Fungsi untuk menghitung luas dan keliling
def hitung():
    try:
        if bangun_var.get() == "Persegi":
            #Lengkapi kode berikut
            label_hasil.config(text=f"Luas: {luas} | Keliling: {keliling}")
        elif bangun_var.get() == "Persegi Panjang":
            panjang = float(entry_panjang.get())  # Mengambil nilai panjang dari entry
            #Lengkapi kode berikut
        elif bangun_var.get() == "Lingkaran":
            jari_jari = float(entry_jari_jari.get())  # Mengambil nilai jari-jari dari entry
            luas = #Lengkapi kode berikut  # Menghitung luas lingkaran (π * r²)
            keliling = 2 * 3.14 * jari_jari  # Menghitung keliling lingkaran (2 * π * r)
            label_hasil.config(text=f"Luas: {luas:.2f} | Keliling: {keliling:.2f}")
    except ValueError:
        label_hasil.config(text="Masukkan angka yang valid.")

# Membuat window utama
root = tk.Tk()
#Lengkapi kode berikut

# Membuat label untuk memilih bangun datar
label_bangun = tk.Label(root, text="Pilih Bangun Datar:", font=("Arial", 12))
label_bangun.pack(pady=10)

# Opsi untuk memilih bangun datar
bangun_var = tk.StringVar()
bangun_var.set("Persegi")  # Default pilihan

radio_persegi = tk.Radiobutton(root, text="Persegi", variable=bangun_var, value="Persegi", font=("Arial", 12))
radio_persegi.pack()

radio_persegi_panjang = tk.Radiobutton(root, text="Persegi Panjang", variable=bangun_var, value="Persegi Panjang", font=("Arial", 12))
radio_persegi_panjang.pack()

radio_lingkaran = tk.Radiobutton(root, text="Lingkaran", variable=bangun_var, value="Lingkaran", font=("Arial", 12))
radio_lingkaran.pack()

# Label dan entry untuk input sesuai dengan pilihan
label_sisi = tk.Label(root, text="Masukkan sisi (untuk Persegi):", font=("Arial", 10))
label_panjang = tk.Label(root, text="Masukkan panjang (untuk Persegi Panjang):", font=("Arial", 10))
label_lebar = tk.Label(root, text="Masukkan lebar (untuk Persegi Panjang):", font=("Arial", 10))
label_jari_jari = tk.Label(root, text="Masukkan jari-jari (untuk Lingkaran):", font=("Arial", 10))

entry_sisi = tk.Entry(root, font=("Arial", 12))
entry_panjang = tk.Entry(root, font=("Arial", 12))
entry_lebar = tk.Entry(root, font=("Arial", 12))
entry_jari_jari = tk.Entry(root, font=("Arial", 12))

# Fungsi untuk mengupdate form input sesuai dengan bangun yang dipilih
def update_form():
    if bangun_var.get() == "Persegi":
        label_sisi.pack(pady=5)
        entry_sisi.pack(pady=5)
        label_panjang.pack_forget()
        entry_panjang.pack_forget()
        label_lebar.pack_forget()
        entry_lebar.pack_forget()
        label_jari_jari.pack_forget()
        entry_jari_jari.pack_forget()
    elif bangun_var.get() == "Persegi Panjang":
        label_sisi.pack_forget()
        entry_sisi.pack_forget()
        label_panjang.pack(pady=5)
        entry_panjang.pack(pady=5)
        label_lebar.pack(pady=5)
        entry_lebar.pack(pady=5)
        label_jari_jari.pack_forget()
        entry_jari_jari.pack_forget()
    elif bangun_var.get() == "Lingkaran":
        label_sisi.pack_forget()
        entry_sisi.pack_forget()
        label_panjang.pack_forget()
        entry_panjang.pack_forget()
        label_lebar.pack_forget()
        entry_lebar.pack_forget()
        label_jari_jari.pack(pady=5)
        entry_jari_jari.pack(pady=5)

update_form()  # Memperbarui form input sesuai pilihan awal

# Tombol untuk menghitung
button_hitung = tk.Button(#Lengkapi kode berikut)
button_hitung.pack(pady=20)

# Label untuk menampilkan hasil perhitungan
label_hasil = tk.Label(#Lengkapi kode berikut)
label_hasil.pack(pady=20)

# Mengupdate form input jika pilihan bangun datar berubah
bangun_var.trace("w", lambda *args: update_form())

# Menjalankan aplikasi
root.mainloop()
